# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# The clean data Frame holds 248 mice
#
# The Bar Graph shows that Drug Regimen Capomulin has the highest mice number followed by Ramicane.
#
# The Bar Graph also shows that the The Bar Graph shows that Drug Regimen Zoniferol hsa the smallest mice number

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np



# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)


# Combine the data into a single dataset

combine_df = pd.merge(mouse_metadata, study_results,)


# Display the data table for preview
combine_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
len(combine_df["Mouse ID"].unique())
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 

duplicate_mouse_ids = combine_df.loc[combine_df.duplicated(["Mouse ID", "Timepoint"]),"Mouse ID"].unique()
duplicate_mouse_ids
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mouse_data = combine_df.loc[combine_df["Mouse ID"] == "g989", :]
duplicate_mouse_data
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
new_df = combine_df[combine_df["Mouse ID"].isin(duplicate_mouse_ids)==False]

new_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice in the clean DataFrame.
len(new_df["Mouse ID"].value_counts())
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
mean = new_df["Tumor Volume (mm3)"].groupby(new_df["Drug Regimen"]).mean()
meadian = new_df["Tumor Volume (mm3)"].groupby(new_df["Drug Regimen"]).median()
var = new_df["Tumor Volume (mm3)"].groupby(new_df["Drug Regimen"]).var()
std = new_df["Tumor Volume (mm3)"].groupby(new_df["Drug Regimen"]).std()
sem = new_df["Tumor Volume (mm3)"].groupby(new_df["Drug Regimen"]).sem()

# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.

summary_stats = pd.DataFrame({"Mean Tumor Volume":mean,
                             "Median Tumor Volume":meadian,
                             "Tumor Volume Variane":std,
                             "Tumor Volume std. Dev.":var,
                             "Tumor Volume std. Err.":sem})

summary_stats
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variane  \
# Drug Regimen
# Capomulin             40.675741            41.557809              4.994774
# Ceftamin              52.591172            51.776157              6.268188
# Infubinol             52.884795            51.820584              6.567243
# Ketapril              55.235638            53.698743              8.279709
# Naftisol              54.331565            52.509285              8.134708
# Placebo               54.033581            52.288934              7.821003
# Propriva              52.320930            50.446266              6.622085
# Ramicane              40.216745            40.673236              4.846308
# Stelasyn              54.233149            52.431737              7.710419
# Zoniferol             53.236507            51.818479              6.966589
#
#               Tumor Volume std. Dev.  Tumor Volume std. Err.
# Drug Regimen
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line.
aggregation = new_df.groupby(["Drug Regimen"])[["Tumor Volume (mm3)"]].agg(["mean", "median", "var", "std", "sem"])

aggregation
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
mice_tested = new_df["Drug Regimen"].value_counts()

#mice_tested
plot_pandas = mice_tested.plot.bar("b")
plt.xlable=("Drug Regimen")
plt.ylabel=("Number Of Mice")
plt.title("Number Of Mice Tested Per Treatment")
plt.figure(figsize=(20,5));

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.

x_axis = mice_tested.index.values
y_axis = mice_tested.values

plt.bar(x_axis, y_axis, alpha=0.9, align="center")

#x_axis
#y_axis

plt.title("Number Of Mice Tested Per Treatment")
plt.ylabel=("Number Of Mice")
plt.xlable=("Drug Regimen")
plt.xticks(rotation="vertical")

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
Male_vs_female = new_df["Sex"].value_counts()
plt.title("Female versus male Mice")
Male_vs_female.plot.pie(autopct="%1.1f%%")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
plt.title("Female vs Male Distribution")
label= ["Male", "Female"]
sizes = [49.0, 51.0]
pie_plot = Male_vs_female.plot.pie(y="Total count", autopct="%1.1f%%")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

Capomulin = new_df.loc[new_df["Drug Regimen"] == "Capomulin",:]
Ramicane = new_df.loc[new_df["Drug Regimen"] == "Ramicane", :]
Infubinol = new_df.loc[new_df["Drug Regimen"] == "Infubinol", :]
Ceftamin = new_df.loc[new_df["Drug Regimen"] == "Ceftamin", :]

# Start by getting the last (greatest) timepoint for each mouse

Capomulin_last = Capomulin.groupby('Mouse ID').max()['Timepoint']
Capomulin_volume = pd.DataFrame(Capomulin_last)
Capomulin_merge = pd.merge(Capomulin_volume, new_df, on=("Mouse ID","Timepoint"),how="left")
Capomulin_merge.head()
# Out:
#   Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0     b128         45    Capomulin  Female           9          22
# 1     b742         45    Capomulin    Male           7          21
# 2     f966         20    Capomulin    Male          16          17
# 3     g288         45    Capomulin    Male           3          19
# 4     g316         45    Capomulin  Female          22          22
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           38.982878                 2
# 1           38.939633                 0
# 2           30.485985                 0
# 3           37.074024                 1
# 4           40.159220                 2

# %%
# Put treatments into a list for for loop (and later for plot labels)
# Create empty list to fill with tumor vol data (for plotting)
# Calculate the IQR and quantitatively determine if there are any potential outliers.



    
# Locate the rows which contain mice on each drug and get the tumor volumes
# add subset 
# Determine outliers using upper and lower bounds

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
